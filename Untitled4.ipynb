# %% [markdown]
# <a href="https://colab.research.google.com/github/rrohan1920/mk-labs-file/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f871c9f7-138d-445e-af1b-22a733f81bba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f871c9f7-138d-445e-af1b-22a733f81bba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
grade_mapping = {
    'O': 10,
    'A+': 9,
    'A': 8,
    'B+': 7,
    'B': 6,
    'C': 5,
    'P': 5,
    'F': 3
    'AB': 0
}


for filename in uploaded.keys():

    df = pd.read_excel(filename)


    df.replace(grade_mapping, inplace=True)


    updated_filename = 'Updated_' + filename
    df.to_excel(updated_filename, index=False)

    files.download(updated_filename)
    print(f"Updated file saved as: {updated_filename}")

print("All files processed and downloaded!")
# Out:
#   File "<ipython-input-11-997e176180c4>", line 9
#     'F': 3
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1   Unnamed: 2     Unnamed: 3      Unnamed: 4  BMA-101  \
# 0      Sr.No     Gender  SGPA(Sem 1)  Total Credits  Earned Credits      4.0
# 1          1       Male       8.6571           17.5            17.5      9.0
# 2          2       Male          8.2           17.5            17.5      8.0
# 3          3       Male       8.3143           17.5            17.5      8.0
# 4          4     Female       7.9429           17.5            17.5      8.0
#
#   BME-102  BCH-100  BCS-101  BCH-151  BCS-151 BCH-MC-002  BHM-100  \
# 0       2      4.0      4.0      1.5      2.0          0      0.0
# 1       9      9.0      8.0      9.0      8.0          8      8.0
# 2       8      9.0      8.0      9.0      7.0          7      5.0
# 3       8      9.0      8.0      9.0      8.0          9      7.0
# 4       8      8.0      8.0      6.0      9.0          8      6.0
#
#            Unnamed: 13
# 0  Sem 1 Backlog Count
# 1                  NaN
# 2                  NaN
# ...

# %%
df.columns = df.columns.str.strip()

print(df.columns)

target_columns = [
    'BMA-101', 'BME-102', 'BCH-100', 'BCS-101',
    'BCH-151', 'BCS-151', 'BCH-MC-002', 'BHM-100'
]

df['Mean'] = df[target_columns].mean(axis=1, numeric_only=True)

print(df.head())


df.to_excel("Updated_Result-Experiment.xlsx", index=False)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'ML Lab', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Project Phase 1',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-6d58121162e8> in <cell line: 0>()
#      12
#      13 # Calculate row-wise mean and add a new 'Mean' column
# ---> 14 df['Mean'] = df[target_columns].mean(axis=1, numeric_only=True)
#      15
#      16 # Show the first 5 rows to verify
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# ...
