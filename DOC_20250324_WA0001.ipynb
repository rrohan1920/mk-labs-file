# %% [markdown]
# <a href="https://colab.research.google.com/github/rrohan1920/mk-labs-file/blob/main/DOC_20250324_WA0001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Result-Experiment-2.xlsx')
df
# Out:
#     Unnamed: 0 Unnamed: 1   Unnamed: 2     Unnamed: 3      Unnamed: 4 BMA-101  \
# 0        Sr.No     Gender  SGPA(Sem 1)  Total Credits  Earned Credits       4
# 1            1       Male       8.6571           17.5            17.5      A+
# 2            2       Male          8.2           17.5            17.5       A
# 3            3       Male       8.3143           17.5            17.5       A
# 4            4     Female       7.9429           17.5            17.5       A
# ..         ...        ...          ...            ...             ...     ...
# 113        113       Male            0            NaN             NaN     NaN
# 114        114       Male            0            NaN             NaN     NaN
# 115        115       Male            0            NaN             NaN     NaN
# 116        116       Male            0              0               0     NaN
# 117        117       Male       8.3429           17.5            17.5      A+
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0 Unnamed: 1   Unnamed: 2     Unnamed: 3      Unnamed: 4 BMA-101  \
# 0        Sr.No     Gender  SGPA(Sem 1)  Total Credits  Earned Credits       4
# 1            1       Male       8.6571           17.5            17.5      A+
# 2            2       Male          8.2           17.5            17.5       A
# 3            3       Male       8.3143           17.5            17.5       A
# 4            4     Female       7.9429           17.5            17.5       A
# ..         ...        ...          ...            ...             ...     ...
# 113        113       Male            0            NaN             NaN     NaN
# 114        114       Male            0            NaN             NaN     NaN
# 115        115       Male            0            NaN             NaN     NaN
# 116        116       Male            0              0               0     NaN
# 117        117       Male       8.3429           17.5            17.5      A+
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'BMA-101', 'BME-102', 'BCH-100', 'BCS-101', 'BCH-151', 'BCS-151',
#        'BCH-MC-002', 'BHM-100', 'Unnamed: 13'],
#       dtype='object')

# %%
df = df.iloc[1:]
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 BMA-101 BME-102  \
# 1            1       Male     8.6571       17.5       17.5      A+      A+
# 2            2       Male        8.2       17.5       17.5       A       A
# 3            3       Male     8.3143       17.5       17.5       A       A
# 4            4     Female     7.9429       17.5       17.5       A       A
# 5            5     Female     7.7429       17.5       17.5      B+      B+
# ..         ...        ...        ...        ...        ...     ...     ...
# 113        113       Male          0        NaN        NaN     NaN     NaN
# 114        114       Male          0        NaN        NaN     NaN     NaN
# 115        115       Male          0        NaN        NaN     NaN     NaN
# 116        116       Male          0          0          0     NaN     NaN
# 117        117       Male     8.3429       17.5       17.5      A+      A+
#
#     BCH-100 BCS-101 BCH-151 BCS-151 BCH-MC-002 BHM-100 Unnamed: 13
# ...

# %%
grade_mapping : dict = {'O':10, 'A+':9 , 'A':8 ,'B+':7,'B':6 ,'C':5 ,'D':4 , 'F':3,'P':4,'DET': 0}

# %%
df = df[df['Unnamed: 2'] != 0]
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 BMA-101 BME-102  \
# 1            1       Male     8.6571       17.5       17.5      A+      A+
# 2            2       Male        8.2       17.5       17.5       A       A
# 3            3       Male     8.3143       17.5       17.5       A       A
# 4            4     Female     7.9429       17.5       17.5       A       A
# 5            5     Female     7.7429       17.5       17.5      B+      B+
# ..         ...        ...        ...        ...        ...     ...     ...
# 106        106     Female     8.4286       17.5       17.5       A      A+
# 107        107       Male     8.2286       17.5       17.5      A+       A
# 108        108       Male        7.6       17.5       17.5       A       A
# 109        109     Female     8.6286       17.5       17.5      A+       A
# 117        117       Male     8.3429       17.5       17.5      A+      A+
#
#     BCH-100 BCS-101 BCH-151 BCS-151 BCH-MC-002 BHM-100 Unnamed: 13
# ...

# %%
columns = ['BMA-101', 'BME-102', 'BCH-100', 'BCS-101', 'BCH-151', 'BCS-151','BCH-MC-002', 'BHM-100']

# %%
def convert_grades(df, columns, grade_mapping):
    for col in columns:
        if col in df.columns:
            df[col] = df[col].map(grade_mapping)
    return df

# %%
df = convert_grades(df.copy(), columns, grade_mapping)

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  BMA-101  BME-102  \
# 1            1       Male     8.6571       17.5       17.5        9      9.0
# 2            2       Male        8.2       17.5       17.5        8      8.0
# 3            3       Male     8.3143       17.5       17.5        8      8.0
# 4            4     Female     7.9429       17.5       17.5        8      8.0
# 5            5     Female     7.7429       17.5       17.5        7      7.0
# ..         ...        ...        ...        ...        ...      ...      ...
# 106        106     Female     8.4286       17.5       17.5        8      9.0
# 107        107       Male     8.2286       17.5       17.5        9      8.0
# 108        108       Male        7.6       17.5       17.5        8      8.0
# 109        109     Female     8.6286       17.5       17.5        9      8.0
# 117        117       Male     8.3429       17.5       17.5        9      9.0
#
# ...

# %%
df = df = df.drop(columns = 'Unnamed: 13')
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  BMA-101  BME-102  \
# 1            1       Male     8.6571       17.5       17.5        9      9.0
# 2            2       Male        8.2       17.5       17.5        8      8.0
# 3            3       Male     8.3143       17.5       17.5        8      8.0
# 4            4     Female     7.9429       17.5       17.5        8      8.0
# 5            5     Female     7.7429       17.5       17.5        7      7.0
# ..         ...        ...        ...        ...        ...      ...      ...
# 106        106     Female     8.4286       17.5       17.5        8      9.0
# 107        107       Male     8.2286       17.5       17.5        9      8.0
# 108        108       Male        7.6       17.5       17.5        8      8.0
# 109        109     Female     8.6286       17.5       17.5        9      8.0
# 117        117       Male     8.3429       17.5       17.5        9      9.0
#
# ...

# %%
display(df)
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  BMA-101  BME-102  \
# 1            1       Male     8.6571       17.5       17.5        9      9.0
# 2            2       Male        8.2       17.5       17.5        8      8.0
# 3            3       Male     8.3143       17.5       17.5        8      8.0
# 4            4     Female     7.9429       17.5       17.5        8      8.0
# 5            5     Female     7.7429       17.5       17.5        7      7.0
# ..         ...        ...        ...        ...        ...      ...      ...
# 106        106     Female     8.4286       17.5       17.5        8      9.0
# 107        107       Male     8.2286       17.5       17.5        9      8.0
# 108        108       Male        7.6       17.5       17.5        8      8.0
# 109        109     Female     8.6286       17.5       17.5        9      8.0
# 117        117       Male     8.3429       17.5       17.5        9      9.0
#
# ...

# %%
df[columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c59db0990343> in <cell line: 0>()
# ----> 1 df[columns]
#
# NameError: name 'df' is not defined
