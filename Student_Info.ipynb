# %% [markdown]
# <a href="https://colab.research.google.com/github/rrohan1920/mk-labs-file/blob/main/Student_Info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('/content/Student-List-Exp.xlsx')

specific_data = df.loc[31, ['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN','Roll No.', 'University Registration No. (Issued by R&S Branch)', 'Semester']]
print(specific_data)
# Out:
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN    MANAN KANT AGARWAL
# Roll No.                                                                                       1/22/FET/BCS/034
# University Registration No. (Issued by R&S Branch)                                                  22/FET/0091
# Semester                                                                                                  5CSA2
# Name: 31, dtype: object

# %%
file_name = 'Student-List-Exp.xlsx'

df = pd.read_excel(file_name)

num_rows = df.shape
num_columns = df.shape

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: (63, 19)
# Number of columns: (63, 19)

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    S.No. Semester                           Branch /Course  \
# 0    NaN      NaN                                      NaN
# 1    1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2    2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3    3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4    4.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                                NaN
# 1                                        22/FET/0062
# 2                                        22/FET/0063
# 3                                        22/FET/0064
# ...

# %%
r, c = df.shape
print("Rows:", r)
print("Columns:", c)
# Out:
# Rows: 63
# Columns: 19

# %%
gender_count = df['Gender'].value_counts()
print(gender_count)
# Out:
# Gender
# MALE             48
# FEMALE           13
# Male / Female     1
# Name: count, dtype: int64

# %%
state_count = df['State'].value_counts()
print(state_count)
# Out:
# State
# HARYANA          33
# DELHI            12
# BIHAR             6
# UP                2
# UTTAR PRADESH     1
# RAJASTHAN         1
# Haryana           1
# 0                 1
# NEPAL             1
# ODISHA            1
# West Bengal       1
# Name: count, dtype: int64

# %%
cat_count = df['Category'].value_counts()
print(cat_count)
# Out:
# Category
# GENERAL                    48
# OBC                        13
# Gen./SC/ST/OBC / Others     1
# Name: count, dtype: int64

# %%
p_d = "Total Due Fee for Current Semester / (Previous semester if pending)"
print("Pending Dues:", df[p_d].sum())
# Out:
# Pending Dues: 477519.72

# %%
null_value = df.isnull().sum().sum()
print("Total NULL Values: ",null_value)
print("NaN count per column:")
print(column_nan_count)

rows_with_nulls = df[df.isnull().any(axis=1)]

if not rows_with_nulls.empty:
    print("Records with null values:")
    print(rows_with_nulls)
else:
    print("No records with null values.")
# Out:
# Total NULL Values:  94
# NaN count per column:
# S.No.                                                                                         1
# Semester                                                                                      1
# Branch /Course                                                                                2
# University Registration No. (Issued by R&S Branch)                                            2
# Date of Admission in the Present Class/Course                                                 2
# Roll No.                                                                                      1
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN     0
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN     2
# Gender                                                                                        1
# ...

# %%
spd = df[p_d]>0
print(df[spd]['Roll No.'])
# Out:
# 15    1/22/FET/BCS/017
# 24    1/22/FET/BCS/027
# 39    1/22/FET/BCS/043
# Name: Roll No., dtype: object

# %%
name = 'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN'
print(df[spd][['Roll No.', name, 'mentors']])
# Out:
#             Roll No.  \
# 15  1/22/FET/BCS/017
# 24  1/22/FET/BCS/027
# 39  1/22/FET/BCS/043
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 15                                        HARSH SINGH
# 24                                     ASHUTOSH KUMAR
# 39                                         PIYUSH RAJ
#
#             mentors
# 15   Dr ROSY MADAAN
# 24   Dr RACHNA BEHL
# 39  Dr GINNI SEHGAL

# %%
mn = df['mentors'].isin(['Dr POONAM NANDAL'])
print(df[mn][['Roll No.', name]])
# Out:
#            Roll No.  \
# 5  1/22/FET/BCS/006
# 6  1/22/FET/BCS/007
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 5                                       SHIVAM SINGH
# 6                                         ATUL KUMAR

# %%
ad = df['Aadhaar No. of Student'].isnull()
print(df[ad][['Roll No.', name]])
# Out:
#             Roll No.  \
# 0                NaN
# 7   1/22/FET/BCS/008
# 62      12401005M002
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 0                                     Name of Student
# 7                                            ABHISHEK
# 62                                         YASH YADAV

# %%
ml = df['Gender'].isin(['MALE'])
print(df[ml][['Roll No.', name]])
# Out:
#              Roll No.  \
# 1    1/22/FET/BCS/002
# 3    1/22/FET/BCS/004
# 4    1/22/FET/BCS/005
# 5    1/22/FET/BCS/006
# 6    1/22/FET/BCS/007
# 7    1/22/FET/BCS/008
# 8    1/22/FET/BCS/009
# 10   1/22/FET/BCS/011
# 11   1/22/FET/BCS/012
# 12   1/22/FET/BCS/014
# 13   1/22/FET/BCS/015
# 14   1/22/FET/BCS/016
# 15   1/22/FET/BCS/017
# 16   1/22/FET/BCS/018
# 17   1/22/FET/BCS/019
# 18   1/22/FET/BCS/020
# 19   1/22/FET/BCS/021
# 21   1/22/FET/BCS/023
# 23   1/22/FET/BCS/026
# 24   1/22/FET/BCS/027
# 27   1/22/FET/BCS/030
# 28   1/22/FET/BCS/031
# 29   1/22/FET/BCS/032
# 31   1/22/FET/BCS/034
# 32  1/21/FET/BCS /035
# 33   1/22/FET/BCS/036
# 36   1/22/FET/BCS/039
# 37   1/22/FET/BCS/041
# 39   1/22/FET/BCS/043
# 40   1/22/FET/BCS/044
# 41   1/22/FET/BCS/045
# 42   1/22/FET/BCS/046
# 43   1/22/FET/BCS/047
# 44   1/22/FET/BCS/048
# 45   1/22/FET/BCS/049
# 46   1/22/FET/BCS/050
# 48   1/22/FET/BCS/052
# 49   1/22/FET/BCS/053
# 50   1/22/FET/BCS/054
# 51   1/22/FET/BCS/055
# ...

# %%
df.rename(columns={name:'Name of Students'})
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#     S.No. Semester                           Branch /Course  \
# 0     NaN      NaN                                      NaN
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..    ...      ...                                      ...
# 58   58.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
# 60   60.0    5CSA1  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
# ...

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)
plt.show()
